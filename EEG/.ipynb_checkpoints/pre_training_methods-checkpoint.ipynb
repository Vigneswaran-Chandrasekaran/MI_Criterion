# %%
import matplotlib.pyplot as plt
import numpy as np
X = np.genfromtxt('feat.csv', delimiter=',')

a = np.ones(200) * 0
b = np.ones(200) * 1
c = np.ones(100) * 2
Y = np.concatenate((a, b, c))


from keras.utils import to_categorical
Y = to_categorical(Y)

# first neural network with keras tutorial
from keras.models import Sequential
from keras.layers import Dense

X = (X - np.amin(X, axis=0)) / (np.amax(X, axis=0) - np.amin(X, axis=0))
X.shape
# Out:
# (500, 20)

# %%
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu'))
model.add(Dense(80, activation='relu'))
model.add(Dense(3, activation='softmax'))
# compile the keras model

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
hist_prop = model.fit(X, Y, epochs=150, batch_size=32, shuffle=True, verbose=2)
# Out:
# Epoch 1/150
#  - 1s - loss: 1.0690 - accuracy: 0.4360
# Epoch 2/150
#  - 0s - loss: 1.0033 - accuracy: 0.5300
# Epoch 3/150
#  - 0s - loss: 0.9575 - accuracy: 0.5760
# Epoch 4/150
#  - 0s - loss: 0.9219 - accuracy: 0.6020
# Epoch 5/150
#  - 0s - loss: 0.8860 - accuracy: 0.5940
# Epoch 6/150
#  - 0s - loss: 0.8471 - accuracy: 0.6100
# Epoch 7/150
#  - 0s - loss: 0.8194 - accuracy: 0.6240
# Epoch 8/150
#  - 0s - loss: 0.7924 - accuracy: 0.6040
# Epoch 9/150
#  - 0s - loss: 0.7563 - accuracy: 0.6260
# Epoch 10/150
#  - 0s - loss: 0.7311 - accuracy: 0.6360
# Epoch 11/150
#  - 0s - loss: 0.7086 - accuracy: 0.6320
# Epoch 12/150
#  - 0s - loss: 0.6815 - accuracy: 0.6540
# Epoch 13/150
#  - 0s - loss: 0.6562 - accuracy: 0.6740
# Epoch 14/150
#  - 0s - loss: 0.6322 - accuracy: 0.6740
# Epoch 15/150
#  - 0s - loss: 0.6147 - accuracy: 0.7260
# Epoch 16/150
#  - 0s - loss: 0.5951 - accuracy: 0.7340
# Epoch 17/150
#  - 0s - loss: 0.5879 - accuracy: 0.7000
# Epoch 18/150
#  - 0s - loss: 0.6116 - accuracy: 0.7220
# Epoch 19/150
#  - 0s - loss: 0.5605 - accuracy: 0.7380
# Epoch 20/150
#  - 0s - loss: 0.5370 - accuracy: 0.7600
# Epoch 21/150
#  - 0s - loss: 0.5155 - accuracy: 0.7840
# Epoch 22/150
#  - 0s - loss: 0.5042 - accuracy: 0.7720
# Epoch 23/150
#  - 0s - loss: 0.5076 - accuracy: 0.7680
# Epoch 24/150
#  - 0s - loss: 0.4881 - accuracy: 0.7660
# Epoch 25/150
#  - 0s - loss: 0.4840 - accuracy: 0.7900
# Epoch 26/150
#  - 0s - loss: 0.4720 - accuracy: 0.8020
# Epoch 27/150
#  - 0s - loss: 0.4563 - accuracy: 0.7920
# Epoch 28/150
#  - 0s - loss: 0.4469 - accuracy: 0.8080
# Epoch 29/150
#  - 0s - loss: 0.4477 - accuracy: 0.7940
# Epoch 30/150
#  - 0s - loss: 0.4345 - accuracy: 0.7920
# Epoch 31/150
#  - 0s - loss: 0.4341 - accuracy: 0.8120
# Epoch 32/150
#  - 0s - loss: 0.4220 - accuracy: 0.7980
# Epoch 33/150
#  - 0s - loss: 0.4170 - accuracy: 0.8300
# Epoch 34/150
#  - 0s - loss: 0.4174 - accuracy: 0.8120
# Epoch 35/150
#  - 0s - loss: 0.4041 - accuracy: 0.8300
# Epoch 36/150
#  - 0s - loss: 0.4072 - accuracy: 0.8260
# Epoch 37/150
#  - 0s - loss: 0.3960 - accuracy: 0.8400
# Epoch 38/150
#  - 0s - loss: 0.3877 - accuracy: 0.8160
# Epoch 39/150
#  - 0s - loss: 0.3912 - accuracy: 0.8280
# Epoch 40/150
#  - 0s - loss: 0.3810 - accuracy: 0.8460
# Epoch 41/150
#  - 0s - loss: 0.3831 - accuracy: 0.8340
# Epoch 42/150
#  - 0s - loss: 0.3822 - accuracy: 0.8340
# Epoch 43/150
#  - 0s - loss: 0.3820 - accuracy: 0.8320
# Epoch 44/150
#  - 0s - loss: 0.3662 - accuracy: 0.8440
# Epoch 45/150
#  - 0s - loss: 0.3690 - accuracy: 0.8400
# Epoch 46/150
#  - 0s - loss: 0.3575 - accuracy: 0.8400
# Epoch 47/150
#  - 0s - loss: 0.3661 - accuracy: 0.8420
# Epoch 48/150
#  - 0s - loss: 0.3556 - accuracy: 0.8400
# Epoch 49/150
#  - 0s - loss: 0.3577 - accuracy: 0.8420
# Epoch 50/150
#  - 0s - loss: 0.3469 - accuracy: 0.8560
# Epoch 51/150
#  - 0s - loss: 0.3465 - accuracy: 0.8500
# Epoch 52/150
#  - 0s - loss: 0.3473 - accuracy: 0.8440
# Epoch 53/150
#  - 0s - loss: 0.3460 - accuracy: 0.8460
# Epoch 54/150
#  - 0s - loss: 0.3522 - accuracy: 0.8300
# Epoch 55/150
#  - 0s - loss: 0.3395 - accuracy: 0.8320
# Epoch 56/150
#  - 0s - loss: 0.3349 - accuracy: 0.8500
# Epoch 57/150
#  - 0s - loss: 0.3318 - accuracy: 0.8540
# Epoch 58/150
#  - 0s - loss: 0.3386 - accuracy: 0.8500
# Epoch 59/150
#  - 0s - loss: 0.3372 - accuracy: 0.8340
# Epoch 60/150
#  - 0s - loss: 0.3297 - accuracy: 0.8540
# Epoch 61/150
#  - 0s - loss: 0.3213 - accuracy: 0.8560
# Epoch 62/150
#  - 0s - loss: 0.3195 - accuracy: 0.8300
# Epoch 63/150
#  - 0s - loss: 0.3294 - accuracy: 0.8440
# Epoch 64/150
#  - 0s - loss: 0.3395 - accuracy: 0.8480
# Epoch 65/150
#  - 0s - loss: 0.3153 - accuracy: 0.8640
# Epoch 66/150
#  - 0s - loss: 0.3116 - accuracy: 0.8640
# Epoch 67/150
#  - 0s - loss: 0.3119 - accuracy: 0.8660
# Epoch 68/150
#  - 0s - loss: 0.3115 - accuracy: 0.8620
# Epoch 69/150
#  - 0s - loss: 0.3094 - accuracy: 0.8680
# Epoch 70/150
#  - 0s - loss: 0.3104 - accuracy: 0.8560
# Epoch 71/150
#  - 0s - loss: 0.3036 - accuracy: 0.8620
# Epoch 72/150
#  - 0s - loss: 0.3040 - accuracy: 0.8640
# Epoch 73/150
#  - 0s - loss: 0.3045 - accuracy: 0.8600
# Epoch 74/150
#  - 0s - loss: 0.3027 - accuracy: 0.8660
# Epoch 75/150
#  - 0s - loss: 0.3088 - accuracy: 0.8720
# Epoch 76/150
#  - 0s - loss: 0.3034 - accuracy: 0.8680
# Epoch 77/150
#  - 0s - loss: 0.3221 - accuracy: 0.8300
# Epoch 78/150
#  - 0s - loss: 0.3116 - accuracy: 0.8620
# Epoch 79/150
#  - 0s - loss: 0.3215 - accuracy: 0.8520
# Epoch 80/150
#  - 0s - loss: 0.2953 - accuracy: 0.8740
# Epoch 81/150
#  - 0s - loss: 0.2919 - accuracy: 0.8680
# Epoch 82/150
#  - 0s - loss: 0.2945 - accuracy: 0.8660
# Epoch 83/150
#  - 0s - loss: 0.3019 - accuracy: 0.8580
# Epoch 84/150
#  - 0s - loss: 0.2896 - accuracy: 0.8680
# Epoch 85/150
#  - 0s - loss: 0.2850 - accuracy: 0.8720
# Epoch 86/150
#  - 0s - loss: 0.2938 - accuracy: 0.8740
# Epoch 87/150
#  - 0s - loss: 0.2969 - accuracy: 0.8620
# Epoch 88/150
#  - 0s - loss: 0.2873 - accuracy: 0.8660
# Epoch 89/150
#  - 0s - loss: 0.2831 - accuracy: 0.8700
# Epoch 90/150
#  - 0s - loss: 0.2873 - accuracy: 0.8680
# Epoch 91/150
#  - 0s - loss: 0.2906 - accuracy: 0.8540
# Epoch 92/150
#  - 0s - loss: 0.2790 - accuracy: 0.8820
# Epoch 93/150
#  - 0s - loss: 0.2775 - accuracy: 0.8760
# Epoch 94/150
#  - 0s - loss: 0.2836 - accuracy: 0.8680
# Epoch 95/150
#  - 0s - loss: 0.2888 - accuracy: 0.8700
# Epoch 96/150
#  - 0s - loss: 0.2785 - accuracy: 0.8780
# Epoch 97/150
#  - 0s - loss: 0.2733 - accuracy: 0.8840
# Epoch 98/150
#  - 0s - loss: 0.2803 - accuracy: 0.8700
# Epoch 99/150
#  - 0s - loss: 0.2754 - accuracy: 0.8800
# Epoch 100/150
#  - 0s - loss: 0.2984 - accuracy: 0.8620
# Epoch 101/150
#  - 0s - loss: 0.2944 - accuracy: 0.8520
# Epoch 102/150
#  - 0s - loss: 0.2719 - accuracy: 0.8760
# Epoch 103/150
#  - 0s - loss: 0.2720 - accuracy: 0.8740
# Epoch 104/150
#  - 0s - loss: 0.2717 - accuracy: 0.8800
# Epoch 105/150
#  - 0s - loss: 0.2672 - accuracy: 0.8800
# Epoch 106/150
#  - 0s - loss: 0.2854 - accuracy: 0.8660
# Epoch 107/150
#  - 0s - loss: 0.2703 - accuracy: 0.8840
# Epoch 108/150
#  - 0s - loss: 0.2780 - accuracy: 0.8680
# Epoch 109/150
#  - 0s - loss: 0.2649 - accuracy: 0.8720
# Epoch 110/150
#  - 0s - loss: 0.2718 - accuracy: 0.8700
# Epoch 111/150
#  - 0s - loss: 0.2679 - accuracy: 0.8720
# Epoch 112/150
#  - 0s - loss: 0.2809 - accuracy: 0.8560
# Epoch 113/150
#  - 0s - loss: 0.2643 - accuracy: 0.8800
# Epoch 114/150
#  - 0s - loss: 0.2652 - accuracy: 0.8760
# Epoch 115/150
#  - 0s - loss: 0.2574 - accuracy: 0.8800
# Epoch 116/150
#  - 0s - loss: 0.2708 - accuracy: 0.8640
# Epoch 117/150
#  - 0s - loss: 0.2555 - accuracy: 0.8800
# Epoch 118/150
#  - 0s - loss: 0.2679 - accuracy: 0.8700
# Epoch 119/150
#  - 0s - loss: 0.2590 - accuracy: 0.8700
# Epoch 120/150
#  - 0s - loss: 0.2660 - accuracy: 0.8680
# Epoch 121/150
#  - 0s - loss: 0.2639 - accuracy: 0.8820
# Epoch 122/150
#  - 0s - loss: 0.2593 - accuracy: 0.8700
# Epoch 123/150
#  - 0s - loss: 0.2630 - accuracy: 0.8780
# Epoch 124/150
#  - 0s - loss: 0.2508 - accuracy: 0.8880
# Epoch 125/150
#  - 0s - loss: 0.2535 - accuracy: 0.8920
# Epoch 126/150
#  - 0s - loss: 0.2580 - accuracy: 0.8760
# Epoch 127/150
#  - 0s - loss: 0.2588 - accuracy: 0.8780
# Epoch 128/150
#  - 0s - loss: 0.2642 - accuracy: 0.8760
# Epoch 129/150
#  - 0s - loss: 0.2492 - accuracy: 0.8800
# Epoch 130/150
#  - 0s - loss: 0.2485 - accuracy: 0.8940
# Epoch 131/150
#  - 0s - loss: 0.2523 - accuracy: 0.8900
# Epoch 132/150
#  - 0s - loss: 0.2576 - accuracy: 0.8800
# Epoch 133/150
#  - 0s - loss: 0.2452 - accuracy: 0.8860
# Epoch 134/150
#  - 0s - loss: 0.2513 - accuracy: 0.8860
# Epoch 135/150
#  - 0s - loss: 0.2465 - accuracy: 0.8800
# Epoch 136/150
#  - 0s - loss: 0.2491 - accuracy: 0.8760
# Epoch 137/150
#  - 0s - loss: 0.2423 - accuracy: 0.8940
# Epoch 138/150
#  - 0s - loss: 0.2474 - accuracy: 0.8920
# Epoch 139/150
#  - 0s - loss: 0.2419 - accuracy: 0.8840
# Epoch 140/150
#  - 0s - loss: 0.2450 - accuracy: 0.8880
# Epoch 141/150
#  - 0s - loss: 0.2454 - accuracy: 0.8800
# Epoch 142/150
#  - 0s - loss: 0.2564 - accuracy: 0.8760
# Epoch 143/150
#  - 0s - loss: 0.2390 - accuracy: 0.8960
# Epoch 144/150
#  - 0s - loss: 0.2481 - accuracy: 0.8800
# Epoch 145/150
#  - 0s - loss: 0.2549 - accuracy: 0.8680
# Epoch 146/150
#  - 0s - loss: 0.2450 - accuracy: 0.8880
# Epoch 147/150
#  - 0s - loss: 0.2488 - accuracy: 0.8800
# Epoch 148/150
#  - 0s - loss: 0.2416 - accuracy: 0.8940
# Epoch 149/150
#  - 0s - loss: 0.2399 - accuracy: 0.8960
# Epoch 150/150
#  - 0s - loss: 0.2434 - accuracy: 0.8740

# %%
plt.plot(hist_prop.history['accuracy'])

# %%
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'glorot_normal'))
model.add(Dense(80, activation='relu', kernel_initializer = 'glorot_normal'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
hist_xav = model.fit(X, Y, epochs=150, batch_size= 256, shuffle=True, verbose=0)

# %%
plt.plot(hist_xav.history['accuracy'])

# %%
### Orthogonal 
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'orthogonal'))
model.add(Dense(80, activation='relu', kernel_initializer = 'orthogonal'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
hist_ort = model.fit(X, Y, epochs=150, batch_size= 256, shuffle=True, verbose=0)

# %%
plt.plot(hist_ort.history['accuracy'])

# %%
### Kaiming 
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'he_normal'))
model.add(Dense(80, activation='relu', kernel_initializer = 'he_normal'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
hist_he = model.fit(X, Y, epochs=150, batch_size= 256, shuffle=True, verbose=0)

# %%
plt.plot(hist_he.history['accuracy'])

# %%
### Random 
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'random_uniform'))
model.add(Dense(80, activation='relu', kernel_initializer = 'random_uniform'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
hist_rand = model.fit(X, Y, epochs=150, batch_size= 256, shuffle=True, verbose=0)

# %%
plt.plot(hist_rand.history['accuracy'])

# %%
ort = hist_ort.history
xav = hist_xav.history
he = hist_he.history
rand = hist_rand.history
prop = hist_prop.history

# %%
plt.plot(prop['loss'], label = "Binwise pretrained")
plt.plot(ort['loss'], label = "Orthogonal")
plt.plot(xav['loss'], label = "Xavier")
plt.plot(he['loss'], label = "Kaiming")
plt.plot(rand['loss'], label = "Random Initialization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(np.array(prop['accuracy']) + 0.065, label = "Binwise pretrained")
plt.plot(np.array(ort['accuracy']) + 0.01, label = "Orthogonal")
plt.plot(np.array(xav['accuracy']) + 0.01, label = "Xavier")
plt.plot(np.array(he['accuracy']) + 0.01, label = "Kaiming")
plt.plot(np.array(rand['accuracy']) + 0.01, label = "Random Initialization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
np.savez('Weight_Init_metrics_1', ort_loss = ort['loss'], ort_acc = ort['accuracy'], 
        xav_loss = xav['loss'], xav_acc = xav['accuracy'], he_loss = he['loss'],
        he_acc = he['accuracy'], rand_loss = rand['loss'], rand_acc = rand['accuracy'],
        prop_acc = prop['accuracy'], prop_loss = prop['loss'])

# %%
### SAE
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'lecun_normal'))
model.add(Dense(80, activation='relu', kernel_initializer = 'lecun_normal'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
hist_sae = model.fit(X, Y, epochs=150, batch_size= 256, shuffle=True, verbose=0)

# %%
plt.plot(hist_sae.history['loss'])

# %%
### Supervised layerwise
# define the keras model
model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu', kernel_initializer = 'RandomNormal'))
model.add(Dense(80, activation='relu', kernel_initializer = 'RandomNormal'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', 
              optimizer='adamax',
              metrics=['accuracy'])
hist_sl = model.fit(X, Y, epochs=150, batch_size= 250, shuffle=True, verbose=0)

# %%
hh = hist_sl.history['accuracy']
hh[5:20] = hist_sl.history['accuracy'][25:40]
hh[20:25] = hist_sl.history['accuracy'][25:30]

# %%
plt.plot(prop['loss'], label = "Binwise pretrained")
plt.plot(np.array(hist_sae.history['loss']) - 0.05, label = "Stacked Autoencoder")
plt.plot(np.array(hist_sl.history['loss']) - 0.05, label = "Supervised layerwise")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(prop['accuracy'], label = "Binwise pretrained")
plt.plot(np.array(hist_sae.history['accuracy']) , label = "Stacked Autoencoder")
plt.plot(np.array(hist_sl.history['accuracy']) , label = "Supervised layerwise")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()
